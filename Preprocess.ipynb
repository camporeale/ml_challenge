# %%
import pandas as pd
import numpy as np
from spacy.lang.es import Spanish
from spacy.lang.pt import Portuguese
import unicodedata

# %%
df = pd.read_csv('./train.csv')

# %%
df.sample(5)
# Out:
#                                                       title label_quality  \
# 14415687  Pin Stranger Things Broches De Fieltro Bordado...    unreliable
# 9943570                Cdi Guerrero 150 Gm Sunrise + Cuotas    unreliable
# 11637870   Serra Circular 7.1/4 Makita M5801g - 1.050w 127v    unreliable
# 9026692   Lanterna Dianteira Esquerdo Branco Ap Corcel I...    unreliable
# 5317279          Djembé Profesional -  Africano - Artesanal    unreliable
#
#             language                category
# 14415687     spanish             BUTTON_PINS
# 9943570      spanish  MOTORCYCLE_CDI_MODULES
# 11637870  portuguese           ELECTRIC_SAWS
# 9026692   portuguese  CAR_TURN_SIGNAL_LIGHTS
# 5317279      spanish                 DJEMBES

# %%
nlp_es = Spanish()
nlp_pt = Portuguese()

def normalization(sent, lang):
    if lang = 'Spanish':
        
    for tok in 
    
    return sent

# %%
   df.loc[mask_spanish, "tokens"] = df["title"].apply(lambda x: ' '.join([tok.text.lower() for tok in nlp_es.tokenizer(x) if 
                                                                          tok.is_alpha and not (tok.is_digit or tok.is_stop or len(tok.text) == 1)]))

# %%
nlp = Spanish()
for sent in df[0:500]["title"]:
    s = []
    for tok in nlp.tokenizer(sent):
        if tok.is_alpha and not (tok.is_digit or tok.is_stop or len(tok.text) == 1):
            if not tok.is_ascii:
                tok = ''.join(c for c in unicodedata.normalize('NFD', tok.text.lower()) if unicodedata.category(c) != 'Mn')
                print(tok)
                s.append(tok)
            else:
                s.append(tok.text.lower())
    ' '.join(s)
    print(s)
# Out:
# ['hidrolavadora', 'lavor', 'one', 'bar', 'bomba', 'aluminio', 'italia']
# ['placa', 'sonido', 'behringer']
# ['maquina', 'lavar', 'electrolux', 'kilos']
# ['par', 'disco', 'freio', 'diant', 'vent', 'gol', 'fremax']
# pestanas
# pestanas
# ['flashes', 'led', 'pestanas', 'luminoso', 'falso', 'pestanas', 'partido']
# irrigacao
# ['microaspersor', 'irrigacao', 'ultra', 'metros']
# ['raquete', 'clash', 'tour', 'nova']
# camera
# ['kit', 'tripe', 'celular', 'ou', 'camera', 'fotog', 'brinde', 'nf']
# ['filtro', 'ar', 'bonanza']
# ['gatito', 'lunchera', 'neoprene']
# ['condensador', 'bosch', 'vw', 'fusca']
# ['rosario', 'contador', 'billetes', 'uv', 'mg', 'detecta', 'falsos']
# magicos
# ['banhos', 'magicos']
# ['caixa', 'setor', 'hidraulica', 'ford', 'focus']
# ['tupia', 'coluna', 'laminadora', 'fresa', 'mm', 'mdf', 'acm', 'sh']
# ['touca', 'porco', 'com', 'cachecol', 'luva']
# ['projeto', 'unidade', 'hidraulica', 'psi']
# promocao
# ...
